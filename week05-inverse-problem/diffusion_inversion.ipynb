# %% [markdown]
# # Week 5: Diffusion-Coefficient Inversion
# Infer diffusivity from noisy observations generated by the Week 4 forward model.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import optimize

rng = np.random.default_rng(42)

# %% [markdown]
# ## 1. Observations
# Choose a true diffusivity, observation points, and noise model. Keep the random seed fixed.

# %%
true_diffusivity = 0.1
noise_standard_deviation = 0.01
# TODO: generate clean and noisy observations with the Week 4 solver.

# %% [markdown]
# ## 2. Objective and optimisation
# Define a scalar misfit. Use bounds that reflect physically possible diffusivity values.

# %%
def objective(diffusivity):
    # TODO: run the forward model and compare predictions with observations.
    pass

# result = optimize.minimize_scalar(objective, bounds=(TODO, TODO), method="bounded")

# %% [markdown]
# ## 3. Sensitivity and interpretation
# Repeat across noise levels and initial assumptions. Discuss identifiability, uncertainty, and non-uniqueness.
