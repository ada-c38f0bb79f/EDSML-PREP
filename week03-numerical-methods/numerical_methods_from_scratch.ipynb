# %% [markdown]
# # Week 3: Numerical Methods from Scratch
# Implement first, then compare against trusted NumPy/SciPy references.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import optimize

# %% [markdown]
# ## 1. Bisection
# Write the stopping rule, track the residual, and test a valid and invalid bracket.

# %%
def bisection(function, left, right, tolerance=1e-10, max_iterations=100):
    # TODO: validate the bracket and implement the iteration.
    pass

# %% [markdown]
# ## 2. Newton iteration
# Compare convergence speed and failure modes with bisection.

# %%
def newton(function, derivative, initial, tolerance=1e-10, max_iterations=100):
    # TODO: return both the estimate and iteration history.
    pass

# %% [markdown]
# ## 3. Linear systems
# Solve a small system, then report `||Ax-b||` and compare with `numpy.linalg.solve`.

# %%
# TODO: implement or explain your solver.
# TODO: add convergence/error plots and a short interpretation.
