# %% [markdown]
# # Week 3: Conditioning Experiment
# Investigate how a small input perturbation can produce a large solution error.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.linalg import hilbert

# %% [markdown]
# ## 1. Experimental design
# Choose matrix sizes, define a known exact solution, and explain the perturbation applied to `b`.

# %%
sizes = range(2, 13)
# TODO: collect condition numbers, residuals, and forward errors.

# %% [markdown]
# ## 2. Results
# Plot the metrics against matrix size. Distinguish residual from forward error.

# %%
# TODO: run the experiment and create labelled plots.

# %% [markdown]
# ## 3. Interpretation
# TODO: explain what the condition number predicts and what the experiment actually shows.
