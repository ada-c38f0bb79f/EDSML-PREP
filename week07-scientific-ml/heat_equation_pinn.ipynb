# %% [markdown]
# # Week 7: Heat-Equation PINN
# Solve the same problem as Week 4 so the finite-difference solution is a meaningful reference.

# %% [markdown]
# ## Environment
# Choose either PyTorch directly or DeepXDE. Record the exact versions and random seeds; these optional packages are not installed by the root requirements files.

# %%
import matplotlib.pyplot as plt
import numpy as np

SEED = 42
# TODO: import the chosen autodiff framework and set all seeds.

# %% [markdown]
# ## 1. Mathematical problem
# State the PDE residual, domain, initial condition, boundary conditions, and input/output normalisation.

# %% [markdown]
# ## 2. Model and losses
# Define the network and compute PDE derivatives with automatic differentiation. Track PDE, initial-condition, and boundary-condition losses separately.

# %%
# TODO: model, collocation samples, loss terms, and optimiser.

# %% [markdown]
# ## 3. Training
# Document sample counts, loss weights, optimiser settings, stopping rule, and runtime.

# %%
# TODO: training loop and loss-component plot.

# %% [markdown]
# ## 4. Comparison
# Evaluate the PINN and Week 4 solver on one shared grid. Report error, runtime, strengths, and failure modes.

# %%
# TODO: reference comparison, error metrics, and plots.
