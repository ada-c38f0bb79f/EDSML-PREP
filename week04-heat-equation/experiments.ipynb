# %% [markdown]
# # Week 4: 1D Heat-Equation Experiments
# State the PDE, domain, initial condition, boundary conditions, and expected solution behaviour.

# %%
import matplotlib.pyplot as plt
import numpy as np

from heat1d_explicit import solve_heat_explicit
from heat1d_implicit import solve_heat_implicit

# %% [markdown]
# ## 1. Derivation
# Derive the explicit and implicit finite-difference stencils. Define the nondimensional ratio used in the stability condition.

# %%
diffusivity = 0.1
length = 1.0
# TODO: define grids and an initial condition with fixed boundary values.

# %% [markdown]
# ## 2. Verification
# Compare both methods against an analytical or manufactured solution and report an error norm.

# %%
# TODO: run both solvers and create comparison plots.

# %% [markdown]
# ## 3. Stability and refinement
# Vary `dt` across the theoretical explicit threshold, then refine `dx` and measure error.

# %%
# TODO: stability sweep, grid-refinement plot, and interpretation.
