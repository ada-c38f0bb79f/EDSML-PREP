# %% [markdown]
# # Week 2: Environmental Data Analysis
#
# **Research question:** TODO
#
# **Dataset and source:** TODO

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

# %% [markdown]
# ## 1. Load and inspect
# Record dimensions, coordinates, variables, attributes, units, and missing-value conventions before analysis.

# %%
data_path = Path("data/raw/TODO.nc")
# ds = xr.open_dataset(data_path)
# display(ds)

# %% [markdown]
# ## 2. Select and clean
# Use labelled selection with `.sel()`. Explain every filtering choice and verify the units.

# %%
# subset = ds["TODO_variable"].sel(time=slice("TODO", "TODO"))
# cleaned = subset.where(TODO_condition)

# %% [markdown]
# ## 3. Aggregate and visualise
# Compute at least one temporal or spatial aggregation and make two labelled figures.

# %%
# monthly = cleaned.resample(time="MS").mean()
# TODO: time-series plot
# TODO: spatial plot, if latitude and longitude are present

# %% [markdown]
# ## 4. Save and interpret
# Save the processed result, state the answer to the research question, and discuss uncertainty and limitations.

# %%
output_path = Path("data/processed/week02_result.nc")
# output_path.parent.mkdir(parents=True, exist_ok=True)
# monthly.to_netcdf(output_path)
